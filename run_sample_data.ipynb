# %% [markdown]
# # Wells4Hydrogeology Examples

# %% [markdown]
# ## Using sample data

# %% [markdown]
# Sample data from Illinois can be read in using `w4h.get_resources()`. By default, this will read in data from a medium-sized site in western Illinois. However, by setting the `scope='state'` parameter, this will instead read in data at a statewide level in Illinois.
#
# Also by default, `w4h.get_resources()` returns a dictionary of filepaths. This is faster. If instead you would like to return a dictionary with actual data objects, set `resource_type='data'`.

# %%
import w4h
res=w4h.get_resources(resource_type='filepath', scope='state')
res

# %% [markdown]
# This is an example call of `wrh.run()` using the filepaths of the sample data, which were saved on your machine when you installed the w4h package.
#
# Setting `verbose=True` allows you to follow what the program is doing and what parameters are being used.

# %%
results = w4h.run(well_data=res['well_data'],
                surf_elev_grid=res['surf_elev'],
                bedrock_elev_grid=res['bedrock_elev'],
                model_grid=res['model_grid'],
                study_area=res['study_area'],
                lith_dict = res['LithologyDict_Exact'],
                #lith_dict_start = res['LithologyDict_Start'],
                #lith_dict_wildcard = res['LithologyDict_Wildcard'],
                verbose=True
                )
# Out:
# run
# 	Started at 2024-02-14 17:16:18.489699.
# 	Parameters:
# 		well_data=c:\Users\riley\LocalData\Code\Github\wells4hydrogeology\w4h\resources\sample_data\statewide_sample_data\IL_Statewide_WellData_XYz_2023-07-20_cleaned.zip
# 		surf_elev_grid=c:\Users\riley\LocalData\Code\Github\wells4hydrogeology\w4h\resources\sample_data\statewide_sample_data\IL_Statewide_Surface_Elev_ft_625ft_Lambert_GridAlign.tif
# 		bedrock_elev_grid=c:\Users\riley\LocalData\Code\Github\wells4hydrogeology\w4h\resources\sample_data\statewide_sample_data\IL_Statewide_Bedrock_Elev_2023_ft_625ft_Lambert_GridAlign.tif
# 		model_grid=c:\Users\riley\LocalData\Code\Github\wells4hydrogeology\w4h\resources\sample_data\grid_625_raster.tif
# 		metadata=None
# 		layers=9
# 		well_data_cols=None
# 		well_metadata_cols=None
# 		description_col=FORMATION
# 		top_col=TOP
# 		bottom_col=BOTTOM
# 		depth_type=depth
# 		study_area=c:\Users\riley\LocalData\Code\Github\wells4hydrogeology\w4h\resources\sample_data\statewide_sample_data\IL_Statewide_boundary.zip
# 		xcol=LONGITUDE
# 		ycol=LATITUDE
# 		zcol=ELEVATION
# 		well_id_col=API_NUMBER
# 		output_crs=EPSG:4269
# 		lith_dict=c:\Users\riley\LocalData\Code\Github\wells4hydrogeology\w4h\resources\sample_data\DictionaryTerms\DICTIONARY_SearchTerms-Specific_2023-06-27.csv
# 		lith_dict_start=None
# 		lith_dict_wildcard=None
# 		target_dict=None
# 		target_name=
# 		export_dir=None
# 		verbose=True
# 		log=False
# 		kw_params={}
#
#
# file_setup
# 	Started at 2024-02-14 17:16:18.491943.
# 	Parameters:
# 		well_data=<input object>
# 		metadata=None
# 		data_filename=*ISGS_DOWNHOLE_DATA*.txt
# 		metadata_filename=*ISGS_HEADER*.txt
# 		log_dir=None
# 		verbose=True
# 		log=False
# Using the following file(s):
# 	 c:\Users\riley\LocalData\Code\Github\wells4hydrogeology\w4h\resources\sample_data\statewide_sample_data\IL_Statewide_WellData_XYz_2023-07-20_cleaned.zip
#
#
# read_raw_csv
# 	Started at 2024-02-14 17:16:18.493644.
# 	Parameters:
# 		data_filepath=c:\Users\riley\LocalData\Code\Github\wells4hydrogeology\w4h\resources\sample_data\statewide_sample_data\IL_Statewide_WellData_XYz_2023-07-20_cleaned.zip
# 		metadata_filepath=None
# 		data_cols=None
# 		metadata_cols=None
# 		xcol=LONGITUDE
# 		ycol=LATITUDE
# 		well_key=API_NUMBER
# 		encoding=latin-1
# 		verbose=True
# 		log=False
# 		read_csv_kwargs
# Data file has 2249838 valid well records.
#
#
# define_dtypes
# 	Started at 2024-02-14 17:16:22.688076.
# 	Parameters:
# 		undefined_df=<input object>
# 		datatypes=./resources/downholeDataTypes.txt
# 		verbose=True
# 		log=False
# ERROR: datatypes file 'resources\downholeDataTypes.txt' does not exist, using inferred datatypes.
#
#
# define_dtypes
# 	Started at 2024-02-14 17:16:22.739002.
# 	Parameters:
# 		undefined_df=<input object>
# 		datatypes=./resources/headerDataTypes.txt
# 		verbose=True
# 		log=False
#
#
# read_grid
# 	Started at 2024-02-14 17:16:40.076772.
# 	Parameters:
# 		grid_path=c:\Users\riley\LocalData\Code\Github\wells4hydrogeology\w4h\resources\sample_data\grid_625_raster.tif
# 		grid_type=model
# 		no_data_val_grid=0
# 		use_service=False
# 		study_area=<input object>
# 		study_area_crs=None
# 		grid_crs=None
# 		verbose=True
# 		log=False
# 		kwargs
#
#
# read_model_grid
# 	Started at 2024-02-14 17:16:40.077807.
# 	Parameters:
# 		model_grid_path=c:\Users\riley\LocalData\Code\Github\wells4hydrogeology\w4h\resources\sample_data\grid_625_raster.tif
# 		study_area=<input object>
# 		no_data_val_grid=0
# 		read_grid=True
# 		node_byspace=True
# 		study_area_crs=None
# 		grid_crs=None
# 		verbose=True
# 		log=False
#
#
# read_grid
# 	Started at 2024-02-14 17:16:49.260697.
# 	Parameters:
# 		grid_path=c:\Users\riley\LocalData\Code\Github\wells4hydrogeology\w4h\resources\sample_data\statewide_sample_data\IL_Statewide_Surface_Elev_ft_625ft_Lambert_GridAlign.tif
# 		grid_type=surface
# 		no_data_val_grid=0
# 		use_service=False
# 		study_area=<input object>
# 		study_area_crs=None
# 		grid_crs=None
# 		verbose=True
# 		log=False
# 		kwargs
#
#
# read_grid
# 	Started at 2024-02-14 17:16:58.523671.
# 	Parameters:
# 		grid_path=c:\Users\riley\LocalData\Code\Github\wells4hydrogeology\w4h\resources\sample_data\statewide_sample_data\IL_Statewide_Bedrock_Elev_2023_ft_625ft_Lambert_GridAlign.tif
# 		grid_type=bedrock
# 		no_data_val_grid=0
# 		use_service=False
# 		study_area=<input object>
# 		study_area_crs=None
# 		grid_crs=None
# 		verbose=True
# 		log=False
# 		kwargs
#
#
# add_control_points
# 	Started at 2024-02-14 17:17:07.407332.
# 	Parameters:
# 		df_without_control=<input object>
# 		df_control=<input object>
# 		xcol=LONGITUDE
# 		ycol=LATITUDE
# 		zcol=ELEVATION
# 		controlpoints_crs=EPSG:4269
# 		description_col=FORMATION
# 		interp_col=INTERPRETATION
# 		target_col=TARGET
# 		verbose=True
# 		log=False
# 		kwargs
# 			top_col=TOP
# 			bottom_col=BOTTOM
#
#
# remove_nonlocated
# 	Started at 2024-02-14 17:17:07.408310.
# 	Parameters:
# 		df_with_locations=<input object>
# 		xcol=LONGITUDE
# 		ycol=LATITUDE
# 		no_data_val_table=
# 		verbose=True
# 		log=False
# Removed well records with no location information.
# 	Number of records before removing: 2244389
# 	Number of records after removing: 2244389
# 		0 wells records removed without location information
#
#
# remove_no_topo
# 	Started at 2024-02-14 17:17:07.945532.
# 	Parameters:
# 		df_with_topo=<input object>
# 		zcol=ELEVATION
# 		no_data_val_table=
# 		verbose=True
# 		log=False
# Removed well records with no surface elevation information.
# 	Number of records before removing: 2244389
# 	Number of records after removing: 2244389
# 		0 wells records removed without surface elevation information
#
#
# remove_no_depth
# 	Started at 2024-02-14 17:17:08.223748.
# 	Parameters:
# 		df_with_depth=<input object>
# 		top_col=TOP
# 		bottom_col=BOTTOM
# 		no_data_val_table=
# 		verbose=True
# 		log=False
# Removed well records with no depth information.
# 	Number of records before removing: 2244389
# 	Number of records after removing: 2244389
# 		0 well records removed without depth information
#
#
# remove_bad_depth
# 	Started at 2024-02-14 17:17:08.847682.
# 	Parameters:
# 		df_with_depth=<input object>
# 		top_col=TOP
# 		bottom_col=BOTTOM
# 		depth_type=depth
# 		verbose=True
# 		log=False
# Removed well records with obviously bad depth information.
# 	Number of records before removing: 2244389
# 	Number of records after removing: 2241907
# 		2482 well records removed without depth information
#
#
# remove_no_description
# 	Started at 2024-02-14 17:17:09.379087.
# 	Parameters:
# 		df_with_descriptions=<input object>
# 		description_col=FORMATION
# 		no_data_val_table=
# 		verbose=True
# 		log=False
# Removed well records without geologic descriptions.
# 	Number of records before removing: 2241907
# 	Number of records after removing: 2241907
# 		0 well records removed without geologic descriptions
# Search terms to be used:
# 	 {} exact match term/definition pairs
# 	 {} starting match term/definition pairs
# 	 {} wildcard match term/definition pairs
#
#
# specific_define
# 	Started at 2024-02-14 17:17:10.623691.
# 	Parameters:
# 		df=<input object>
# 		terms_df=<input object>
# 		description_col=FORMATION
# 		terms_col=DESCRIPTION
# 		verbose=True
# 		log=False
# Classified well records using exact matches
# 	1794787 records classified using exact matches (80.06% of unclassified data)
# 	447120 records remain unclassified (-79.06% of unclassified data).
#
#
# start_define
# 	Started at 2024-02-14 17:17:15.086520.
# 	Parameters:
# 		df=<input object>
# 		terms_df=<input object>
# 		description_col=FORMATION
# 		terms_col=DESCRIPTION
# 		verbose=True
# 		log=False
# Classified well records using initial substring matches
# 	0 records classified using initial substring matches (0.0% of unclassified  data)
# 	447120 records remain unclassified (1.0% of unclassified  data).
#
#
# wildcard_define
# 	Started at 2024-02-14 17:17:21.109906.
# 	Parameters:
# 		df=<input object>
# 		terms_df=<input object>
# 		description_col=FORMATION
# 		terms_col=DESCRIPTION
# 		verbose=True
# 		log=False
# Classified well records using any substring (wildcard) match
# 	0 records classified using any substring match (0.0% of unclassified  data)
# 	447120 records remain unclassified (1.0% of unclassified  data).
#
#
# depth_define
# 	Started at 2024-02-14 17:17:27.018427.
# 	Parameters:
# 		df=<input object>
# 		top_col=TOP
# 		thresh=550
# 		verbose=True
# 		log=False
# Classified bedrock well records using depth threshold at depth of 550
# 	212580 records classified using bedrock threshold depth (47.54% of unclassified  data)
# 	234540 records remain unclassified (-46.54% of unclassified  data).
#
#
# sample_raster_points
# 	Started at 2024-02-14 17:17:33.689220.
# 	Parameters:
# 		raster=<input object>
# 		points_df=<input object>
# 		well_id_col=API_NUMBER
# 		xcol=LONGITUDE
# 		ycol=LATITUDE
# 		new_col=BEDROCK_ELEV
# 		verbose=True
# 		log=False
# 	Sampling BEDROCK_ELEV grid for at all well locations.
# 	Temporarily reprojecting raster data to point data's CRS.
# c:\Users\riley\LocalData\virtual_envs\w4h_venv\lib\site-packages\rioxarray\raster_writer.py:130: UserWarning: The nodata value (3.402823466e+38) has been automatically changed to (3.4028234663852886e+38) to match the dtype of the data.
#   warnings.warn(
# 	333553 unique wells idenfied using API_NUMBER column
#
#
# sample_raster_points
# 	Started at 2024-02-14 17:23:29.966221.
# 	Parameters:
# 		raster=<input object>
# 		points_df=<input object>
# 		well_id_col=API_NUMBER
# 		xcol=LONGITUDE
# 		ycol=LATITUDE
# 		new_col=SURFACE_ELEV
# 		verbose=True
# 		log=False
# 	Sampling SURFACE_ELEV grid for at all well locations.
# 	Temporarily reprojecting raster data to point data's CRS.
# 	333553 unique wells idenfied using API_NUMBER column
#
#
# layer_interp
# 	Started at 2024-02-14 17:32:01.593347.
# 	Parameters:
# 		points=<input object>
# 		grid=<input object>
# 		layers=9
# 		interp_kind=nearest
# 		return_type=dataarray
# 		export_dir=None
# 		target_col=TARG_THICK_PER
# 		layer_col=LAYER
# 		xcol=None
# 		ycol=None
# 		xcoord=x
# 		ycoord=y
# 		log=False
# 		verbose=True
# 		kwargs
# Interpolating target lithology at each layer:
# 	Completed nearest neighbor interpolation for Layer 1
# 	Completed nearest neighbor interpolation for Layer 2
# 	Completed nearest neighbor interpolation for Layer 3
# 	Completed nearest neighbor interpolation for Layer 4
# 	Completed nearest neighbor interpolation for Layer 5
# 	Completed nearest neighbor interpolation for Layer 6
# 	Completed nearest neighbor interpolation for Layer 7
# 	Completed nearest neighbor interpolation for Layer 8
# 	Completed nearest neighbor interpolation for Layer 9
#
#
# export_grids
# 	Started at 2024-02-14 17:36:51.920651.
# 	Parameters:
# 		grid_data=<input object>
# 		out_path=c:\Users\riley\LocalData\Code\Github\wells4hydrogeology\w4h\resources\sample_data\statewide_sample_data\Output__2024-02-14_17-16-18
# 		file_id=
# 		filetype=tif
# 		variable_sep=True
# 		date_stamp=True
# 		verbose=True
# 		log=False
# Export filepath(s):
# 	 c:/Users/riley/LocalData/Code/Github/wells4hydrogeology/w4h/resources/sample_data/statewide_sample_data/Output__2024-02-14_17-16-18/Layer1_2024-02-14_17-36-51.tif
# 	 c:/Users/riley/LocalData/Code/Github/wells4hydrogeology/w4h/resources/sample_data/statewide_sample_data/Output__2024-02-14_17-16-18/Layer2_2024-02-14_17-36-51.tif
# 	 c:/Users/riley/LocalData/Code/Github/wells4hydrogeology/w4h/resources/sample_data/statewide_sample_data/Output__2024-02-14_17-16-18/Layer3_2024-02-14_17-36-51.tif
# 	 c:/Users/riley/LocalData/Code/Github/wells4hydrogeology/w4h/resources/sample_data/statewide_sample_data/Output__2024-02-14_17-16-18/Layer4_2024-02-14_17-36-51.tif
# 	 c:/Users/riley/LocalData/Code/Github/wells4hydrogeology/w4h/resources/sample_data/statewide_sample_data/Output__2024-02-14_17-16-18/Layer5_2024-02-14_17-36-51.tif
# 	 c:/Users/riley/LocalData/Code/Github/wells4hydrogeology/w4h/resources/sample_data/statewide_sample_data/Output__2024-02-14_17-16-18/Layer6_2024-02-14_17-36-51.tif
# 	 c:/Users/riley/LocalData/Code/Github/wells4hydrogeology/w4h/resources/sample_data/statewide_sample_data/Output__2024-02-14_17-16-18/Layer7_2024-02-14_17-36-51.tif
# 	 c:/Users/riley/LocalData/Code/Github/wells4hydrogeology/w4h/resources/sample_data/statewide_sample_data/Output__2024-02-14_17-16-18/Layer8_2024-02-14_17-36-51.tif
# 	 c:/Users/riley/LocalData/Code/Github/wells4hydrogeology/w4h/resources/sample_data/statewide_sample_data/Output__2024-02-14_17-16-18/Layer9_2024-02-14_17-36-51.tif
